# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
vect = np.asarray([[0.00002],[0.00005],[0.00099],[0.00335],[0.07628],[0.30382],[7.63718],[33.98058],[134.17686],[298.79982]])
lst = np.asarray([[0.00002],[0.00006],[0.00125],[0.00432],[0.10520],[0.42659],[12.19711],[49.08103],[204.48184],[602.99944]])
mp = np.asarray([[0.00003],[0.00004],[0.00024],[0.00043],[0.00253],[0.00522],[0.03422],[0.06913],[0.15030],[0.24341]]) 
elements = np.asarray([[50],[100],[500],[1000],[5000],[10000],[50000],[100000],[200000],[300000]])
fig, ax = plt.subplots()
ax.set_title('Insert Comparison (Int)')
ax.plot(elements, vect, label="Vector")
ax.plot(elements,lst, label="List")
ax.plot(elements,mp, label="Map")
ax.legend(loc="upper left")
plt.xlabel('Number of Elements',fontsize=15)
plt.ylabel('Seconds', fontsize=15)
plt.show()

# %%
vect = np.asarray([[0.00001],[0.00002],[0.00029],[0.00099],[0.02245],[0.08741],[2.27879],[10.07269],[39.58695],[88.22574]])
lst = np.asarray([[0.00001],[0.00004],[0.00028],[0.00101],[0.02578],[0.14174],[7.40935],[35.11698],[144.46305],[740.95815]])
mp = np.asarray([[0.00001],[0.00005],[0.0005],[0.0018],[0.06259],[0.36123],[12.03607],[50.51773],[507.00594],[1773.96418]]) 
elements = np.asarray([[50],[100],[500],[1000],[5000],[10000],[50000],[100000],[200000],[300000]])
fig, ax = plt.subplots()
ax.set_title('Remove Comparison (Int)')
ax.plot(elements, vect, label="Vector")
ax.plot(elements,lst, label="List")
ax.plot(elements,mp, label="Map")
ax.legend(loc="upper left")
plt.xlabel('Number of Elements', fontsize=15)
plt.ylabel('Seconds', fontsize=15)
plt.show()

# %%
vect = np.asarray([[0.12863],[0.34633],[5.7569],[19.68633],[78.02589],[175.01189],[310.53978],[477.543],[679.04384],[894.10435]])
lst = np.asarray([[0.03635],[0.03299],[0.2367],[0.0633],[0.17705],[0.36504],[0.60733],[1.29368],[2.46063],[3.26988]])
mp = np.asarray([[0.03562],[0.07265],[0.39243],[0.73841],[1.52154],[1.66911],[1.91868],[9.74302],[7.727],[11.78527]]) 
elements = np.asarray([[50],[100],[500],[1000],[2000],[3000],[4000],[5000],[6000],[7000]])
fig, ax = plt.subplots()
ax.set_title('Insert Comparison (Big Struct)')
#ax.plot(elements, vect, label="Vector")
ax.plot(elements,lst, label="List")
ax.plot(elements,mp, label="Map")
ax.legend(loc="upper left")
plt.xlabel('Number of Elements', fontsize=15)
plt.ylabel('Seconds', fontsize=15)
plt.show()

# %%
vect = np.asarray([[0.03205],[0.16024],[4.46394],[17.72144],[73.43377],[168.24515],[287.87236],[454.30784],[654.15643],[867.91559]])
lst = np.asarray([[0.00002],[0.00005],[0.00115],[0.00466],[0.02437],[0.08365],[0.19740],[0.38899],[0.67208],[1.04446]])
mp = np.asarray([[0.00766],[0.00009],[0.00179],[0.00693],[0.03110],[0.08372],[0.19631],[0.40685],[0.68685],[0.99287]]) 
elements = np.asarray([[50],[100],[500],[1000],[2000],[3000],[4000],[5000],[6000],[7000]])
fig, ax = plt.subplots()
ax.set_title('Remove Comparison (Big Struct)')
#ax.plot(elements, vect, label="Vector")
ax.plot(elements,lst, label="List")
ax.plot(elements,mp, label="Map")
ax.legend(loc="upper left")
plt.xlabel('Number of Elements', fontsize=15)
plt.ylabel('Seconds', fontsize=15)
plt.show()

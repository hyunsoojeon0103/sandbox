# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
vect = np.asarray([[0.00000090],[0.00000180],[0.00000150],[0.00000190],[0.00000210],[0.00000210],[0.00000520],[0.00003630],[0.00010760],[0.00226970],[0.00964830],[0.25928280],[1.11930300],[5.27165280],[10.21566760]])
lst = np.asarray([[0.00000120],[0.00000120],[0.00000140],[0.00000190],[0.00000210],[0.00000230],[0.00000780],[0.00008110],[0.00033260],[0.02488900],[0.12300810],[6.75009180],[30.30470640],[170.62354630],[502.30968790]])
mp = np.asarray([[0.00001710],[0.00000240],[0.00000250],[0.00000370],[0.00000410],[0.00000490],[0.00002770],[0.00007420],[0.00012500],[0.00074430],[0.00162490],[0.01097750],[0.02643950],[0.07901300],[0.10622980]]) 
elements = np.asarray([[1],[10],[20],[30],[40],[50],[100],[500],[1000],[5000],[10000],[50000],[100000],[200000],[300000]])
fig, ax = plt.subplots()
ax.set_title('Insert Comparison (Int)')
ax.plot(elements, vect, label="Vector")
ax.plot(elements,lst, label="List")
ax.plot(elements,mp, label="Map")
ax.legend(loc="upper left")
plt.xlabel('Number of Elements',fontsize=15)
plt.ylabel('Seconds', fontsize=15)
plt.show()

# %%
vect = np.asarray([[0.00000080],[0.00000090],[0.00000100],[0.00000120],[0.00000130],[0.00000130],[0.00000200],[0.00000890],[0.00003250],[0.00064630],[0.00294170],[0.08484960],[0.41899470],[1.93586860],[4.09644850]])
lst = np.asarray([[0.00000110],[0.00000100],[0.00000120],[0.00000160],[0.00000170],[0.00000190],[0.00000400],[0.00006110],[0.00029200],[0.01676510],[0.12082610],[6.94525890],[30.77264350],[153.64333400],[782.52433680]])
mp = np.asarray([[0.00000410],[0.00000200],[0.00000240],[0.00000390],[0.00000600],[0.00000570],[0.00001480],[0.00021720],[0.00121160],[0.04862050],[0.32020610],[10.48529490],[53.78767710],[482.85974400],[1787.30381350]]) 
elements = np.asarray([[1],[10],[20],[30],[40],[50],[100],[500],[1000],[5000],[10000],[50000],[100000],[200000],[300000]])
fig, ax = plt.subplots()
ax.set_title('Remove Comparison (Int)')
ax.plot(elements, vect, label="Vector")
ax.plot(elements,lst, label="List")
ax.plot(elements,mp, label="Map")
ax.legend(loc="upper left")
plt.xlabel('Number of Elements', fontsize=15)
plt.ylabel('Seconds', fontsize=15)
plt.show()

# %%
vect = np.asarray([[0.00184970],[0.02234070],[0.04233400],[0.05822130],[0.09895400],[0.12472780],[0.32852040],[5.38343070],[22.78463330],[78.33711830],[171.02160840],[316.41939050],[523.41668130],[709.91277580],[951.57460360]])
lst = np.asarray([[0.00115630],[0.00648220],[0.00091250],[0.00134700],[0.00186840],[0.00307990],[0.03286150],[0.23550150],[0.07895890],[0.18654180],[0.34607060],[1.52392820],[2.04031900],[2.62238060],[4.26796250]])
mp = np.asarray([[0.00095210],[0.00708110],[0.00722540],[0.02160000],[0.01376260],[0.02814930],[0.07247400],[0.36558790],[0.79362920],[1.58000680],[1.63755570],[2.53530530],[4.83027490],[7.47924300],[7.38459300]]) 
elements = np.asarray([[1],[10],[20],[30],[40],[50],[100],[500],[1000],[2000],[3000],[4000],[5000],[6000],[7000]])
fig, ax = plt.subplots()
ax.set_title('Insert Comparison (Big Struct)')
#ax.plot(elements, vect, label="Vector")
ax.plot(elements,lst, label="List")
ax.plot(elements,mp, label="Map")
ax.legend(loc="upper left")
plt.xlabel('Number of Elements', fontsize=15)
plt.ylabel('Seconds', fontsize=15)
plt.show()

# %%
vect = np.asarray([[0.00000100],[0.00105030],[0.00353160],[0.01004720],[0.02364830],[0.03018620],[0.14520800],[3.77134860],[17.50040980],[64.11092610],[143.23440800],[282.86902900],[422.91558890],[600.79504980],[818.31872170]])
lst = np.asarray([[0.00007930],[0.00000270],[0.00000410],[0.00000590],[0.00000820],[0.00001010],[0.00002870],[0.00087090],[0.00372590],[0.01808320],[0.07123230],[0.19276970],[0.37401280],[0.70503420],[1.21427120]])
mp = np.asarray([[0.00027160],[0.00145100],[0.00270210],[0.00000870],[0.00572770],[0.00743720],[0.00005160],[0.00178470],[0.00550670],[0.02800650],[0.07368110],[0.20573510],[0.39558900],[0.67895180],[1.00757990]]) 
elements = np.asarray([[1],[10],[20],[30],[40],[50],[100],[500],[1000],[2000],[3000],[4000],[5000],[6000],[7000]])
fig, ax = plt.subplots()
ax.set_title('Remove Comparison (Big Struct)')
#ax.plot(elements, vect, label="Vector")
ax.plot(elements,lst, label="List")
ax.plot(elements,mp, label="Map")
ax.legend(loc="upper left")
plt.xlabel('Number of Elements', fontsize=15)
plt.ylabel('Seconds', fontsize=15)
plt.show()
